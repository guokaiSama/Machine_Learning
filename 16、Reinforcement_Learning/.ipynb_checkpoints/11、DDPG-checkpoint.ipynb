# %% [markdown]
# 使用和DDQN类似的方法：即经验回放和双网络的方法来改进Actor-Critic难收敛的问题，这个算法就是是深度确定性策略梯度(Deep Deterministic Policy Gradient，以下简称DDPG)。

# %%
import tensorflow as tf
import numpy as np
import gym
import time

# %%
MAX_EPISODES = 2000
MAX_EP_STEPS = 200
LR_A = 0.001    # learning rate for actor
LR_C = 0.002    # learning rate for critic
GAMMA = 0.9     # reward discount
TAU = 0.01      # soft replacement
MEMORY_CAPACITY = 10000
BATCH_SIZE = 32

RENDER = False
ENV_NAME = 'Pendulum-v0'

# %%
class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,):
        self.memory = np.zeros((MEMORY_CAPACITY, s_dim * 2 + a_dim + 1), dtype=np.float32)
        self.pointer = 0
        self.sess = tf.Session()

        self.a_dim, self.s_dim, self.a_bound = a_dim, s_dim, a_bound,
        self.S = tf.placeholder(tf.float32, [None, s_dim], 's')
        self.S_ = tf.placeholder(tf.float32, [None, s_dim], 's_')
        self.R = tf.placeholder(tf.float32, [None, 1], 'r')

        with tf.variable_scope('Actor'):
            self.a = self._build_a(self.S, scope='eval', trainable=True)
            a_ = self._build_a(self.S_, scope='target', trainable=False)
        with tf.variable_scope('Critic'):
            # assign self.a = a in memory when calculating q for td_error,
            # otherwise the self.a is from Actor when updating Actor
            q = self._build_c(self.S, self.a, scope='eval', trainable=True)
            q_ = self._build_c(self.S_, a_, scope='target', trainable=False)

        # networks parameters
        self.ae_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/eval')
        self.at_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/target')
        self.ce_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/eval')
        self.ct_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Critic/target')

        # target net replacement
        self.soft_replace = [tf.assign(t, (1 - TAU) * t + TAU * e)
                             for t, e in zip(self.at_params + self.ct_params, self.ae_params + self.ce_params)]

        q_target = self.R + GAMMA * q_
        # in the feed_dic for the td_error, the self.a should change to actions in memory
        td_error = tf.losses.mean_squared_error(labels=q_target, predictions=q)
        self.ctrain = tf.train.AdamOptimizer(LR_C).minimize(td_error, var_list=self.ce_params)

        a_loss = - tf.reduce_mean(q)    # maximize the q
        self.atrain = tf.train.AdamOptimizer(LR_A).minimize(a_loss, var_list=self.ae_params)

        self.sess.run(tf.global_variables_initializer())

    def choose_action(self, s):
        return self.sess.run(self.a, {self.S: s[np.newaxis, :]})[0]

    def learn(self):
        # soft target replacement
        self.sess.run(self.soft_replace)

        indices = np.random.choice(MEMORY_CAPACITY, size=BATCH_SIZE)
        bt = self.memory[indices, :]
        bs = bt[:, :self.s_dim]
        ba = bt[:, self.s_dim: self.s_dim + self.a_dim]
        br = bt[:, -self.s_dim - 1: -self.s_dim]
        bs_ = bt[:, -self.s_dim:]

        self.sess.run(self.atrain, {self.S: bs})
        self.sess.run(self.ctrain, {self.S: bs, self.a: ba, self.R: br, self.S_: bs_})

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, a, [r], s_))
        index = self.pointer % MEMORY_CAPACITY  # replace the old memory with new memory
        self.memory[index, :] = transition
        self.pointer += 1

    def _build_a(self, s, scope, trainable):
        with tf.variable_scope(scope):
            net = tf.layers.dense(s, 30, activation=tf.nn.relu, name='l1', trainable=trainable)
            a = tf.layers.dense(net, self.a_dim, activation=tf.nn.tanh, name='a', trainable=trainable)
            return tf.multiply(a, self.a_bound, name='scaled_a')

    def _build_c(self, s, a, scope, trainable):
        with tf.variable_scope(scope):
            n_l1 = 30
            w1_s = tf.get_variable('w1_s', [self.s_dim, n_l1], trainable=trainable)
            w1_a = tf.get_variable('w1_a', [self.a_dim, n_l1], trainable=trainable)
            b1 = tf.get_variable('b1', [1, n_l1], trainable=trainable)
            net = tf.nn.relu(tf.matmul(s, w1_s) + tf.matmul(a, w1_a) + b1)
            return tf.layers.dense(net, 1, trainable=trainable)  # Q(s,a)

# %%
env = gym.make(ENV_NAME)
env = env.unwrapped
env.seed(1)

s_dim = env.observation_space.shape[0]
a_dim = env.action_space.shape[0]
a_bound = env.action_space.high

ddpg = DDPG(a_dim, s_dim, a_bound)

var = 3  # control exploration
t1 = time.time()
for episode in range(MAX_EPISODES):
    s = env.reset()
    ep_reward = 0
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render()

        # Add exploration noise
        a = ddpg.choose_action(s)
        a = np.clip(np.random.normal(a, var), -2, 2)  # add randomness to action selection for exploration
        s_, r, done, info = env.step(a)

        ddpg.store_transition(s, a, r / 10, s_)

        if ddpg.pointer > MEMORY_CAPACITY:
            var *= .9995  # decay the action randomness
            ddpg.learn()

        s = s_
        ep_reward += r
        if j == MAX_EP_STEPS - 1:
            print('Episode:', episode, ' Reward: %i' % int(ep_reward), 'Explore: %.2f' % var,)
            # if ep_reward > -300:RENDER = True
            break
    if episode % 100 == 0:
        total_reward = 0
        for i in range(10):
            state = env.reset()
            for j in range(MAX_EP_STEPS):
                render = lambda: plt.imshow(env.render(mode='rgb_array'))
                action = ddpg.choose_action(state)  # direct action for test
                state, reward, done, _ = env.step(action)
                total_reward += reward
                if done:
                    break
        ave_reward = total_reward / 300
        print ('episode: ', episode, 'Evaluation Average Reward:', ave_reward)

print('Running time: ', time.time() - t1)
# Out:
# Episode: 0  Reward: -1663 Explore: 3.00
# episode:  0 Evaluation Average Reward: -57.381147774677736
# Episode: 1  Reward: -1755 Explore: 3.00
# Episode: 2  Reward: -1756 Explore: 3.00
# Episode: 3  Reward: -1681 Explore: 3.00
# Episode: 4  Reward: -1568 Explore: 3.00
# Episode: 5  Reward: -1818 Explore: 3.00
# Episode: 6  Reward: -1734 Explore: 3.00
# Episode: 7  Reward: -1542 Explore: 3.00
# Episode: 8  Reward: -1605 Explore: 3.00
# Episode: 9  Reward: -1634 Explore: 3.00
# Episode: 10  Reward: -1725 Explore: 3.00
# Episode: 11  Reward: -1649 Explore: 3.00
# Episode: 12  Reward: -1277 Explore: 3.00
# Episode: 13  Reward: -1684 Explore: 3.00
# Episode: 14  Reward: -1605 Explore: 3.00
# Episode: 15  Reward: -1645 Explore: 3.00
# Episode: 16  Reward: -1640 Explore: 3.00
# Episode: 17  Reward: -1501 Explore: 3.00
# Episode: 18  Reward: -1474 Explore: 3.00
# Episode: 19  Reward: -1478 Explore: 3.00
# Episode: 20  Reward: -1389 Explore: 3.00
# Episode: 21  Reward: -1686 Explore: 3.00
# Episode: 22  Reward: -1153 Explore: 3.00
# Episode: 23  Reward: -1543 Explore: 3.00
# Episode: 24  Reward: -1482 Explore: 3.00
# Episode: 25  Reward: -1666 Explore: 3.00
# Episode: 26  Reward: -1628 Explore: 3.00
# Episode: 27  Reward: -1582 Explore: 3.00
# Episode: 28  Reward: -1736 Explore: 3.00
# Episode: 29  Reward: -1616 Explore: 3.00
# Episode: 30  Reward: -1455 Explore: 3.00
# Episode: 31  Reward: -1784 Explore: 3.00
# Episode: 32  Reward: -1740 Explore: 3.00
# Episode: 33  Reward: -1686 Explore: 3.00
# Episode: 34  Reward: -1530 Explore: 3.00
# Episode: 35  Reward: -1803 Explore: 3.00
# Episode: 36  Reward: -1346 Explore: 3.00
# Episode: 37  Reward: -1789 Explore: 3.00
# Episode: 38  Reward: -1447 Explore: 3.00
# Episode: 39  Reward: -1758 Explore: 3.00
# Episode: 40  Reward: -1529 Explore: 3.00
# Episode: 41  Reward: -1435 Explore: 3.00
# Episode: 42  Reward: -1628 Explore: 3.00
# Episode: 43  Reward: -1711 Explore: 3.00
# Episode: 44  Reward: -1741 Explore: 3.00
# Episode: 45  Reward: -1555 Explore: 3.00
# Episode: 46  Reward: -1778 Explore: 3.00
# Episode: 47  Reward: -1586 Explore: 3.00
# Episode: 48  Reward: -1221 Explore: 3.00
# Episode: 49  Reward: -1538 Explore: 3.00
# Episode: 50  Reward: -1513 Explore: 2.71
# Episode: 51  Reward: -1329 Explore: 2.46
# Episode: 52  Reward: -1799 Explore: 2.22
# Episode: 53  Reward: -1767 Explore: 2.01
# Episode: 54  Reward: -1671 Explore: 1.82
# Episode: 55  Reward: -1677 Explore: 1.65
# Episode: 56  Reward: -1469 Explore: 1.49
# Episode: 57  Reward: -1391 Explore: 1.35
# Episode: 58  Reward: -1343 Explore: 1.22
# Episode: 59  Reward: -1373 Explore: 1.10
# Episode: 60  Reward: -1518 Explore: 1.00
# Episode: 61  Reward: -1216 Explore: 0.90
# Episode: 62  Reward: -1474 Explore: 0.82
# Episode: 63  Reward: -1474 Explore: 0.74
# Episode: 64  Reward: -1520 Explore: 0.67
# Episode: 65  Reward: -1430 Explore: 0.61
# Episode: 66  Reward: -1465 Explore: 0.55
# Episode: 67  Reward: -1587 Explore: 0.50
# Episode: 68  Reward: -1493 Explore: 0.45
# Episode: 69  Reward: -1466 Explore: 0.41
# Episode: 70  Reward: -908 Explore: 0.37
# Episode: 71  Reward: -753 Explore: 0.33
# Episode: 72  Reward: -973 Explore: 0.30
# Episode: 73  Reward: -1020 Explore: 0.27
# Episode: 74  Reward: -790 Explore: 0.25
# Episode: 75  Reward: -911 Explore: 0.22
# Episode: 76  Reward: -825 Explore: 0.20
# Episode: 77  Reward: -884 Explore: 0.18
# Episode: 78  Reward: -805 Explore: 0.16
# Episode: 79  Reward: -794 Explore: 0.15
# Episode: 80  Reward: -403 Explore: 0.14
# Episode: 81  Reward: -659 Explore: 0.12
# Episode: 82  Reward: -122 Explore: 0.11
# Episode: 83  Reward: -263 Explore: 0.10
# Episode: 84  Reward: -1 Explore: 0.09
# Episode: 85  Reward: -116 Explore: 0.08
# Episode: 86  Reward: -271 Explore: 0.07
# Episode: 87  Reward: -132 Explore: 0.07
# Episode: 88  Reward: -133 Explore: 0.06
# Episode: 89  Reward: -504 Explore: 0.05
# Episode: 90  Reward: -379 Explore: 0.05
# Episode: 91  Reward: -266 Explore: 0.04
# Episode: 92  Reward: -491 Explore: 0.04
# Episode: 93  Reward: -1 Explore: 0.04
# Episode: 94  Reward: -257 Explore: 0.03
# Episode: 95  Reward: -4 Explore: 0.03
# Episode: 96  Reward: -5 Explore: 0.03
# Episode: 97  Reward: -129 Explore: 0.02
# Episode: 98  Reward: -244 Explore: 0.02
# Episode: 99  Reward: -133 Explore: 0.02
# Episode: 100  Reward: -133 Explore: 0.02
# episode:  100 Evaluation Average Reward: -7.618615083459705
# Episode: 101  Reward: -129 Explore: 0.02
# Episode: 102  Reward: -243 Explore: 0.01
# Episode: 103  Reward: -4 Explore: 0.01
# Episode: 104  Reward: -131 Explore: 0.01
# Episode: 105  Reward: -130 Explore: 0.01
# Episode: 106  Reward: -272 Explore: 0.01
# Episode: 107  Reward: -269 Explore: 0.01
# Episode: 108  Reward: -4 Explore: 0.01
# Episode: 109  Reward: -6 Explore: 0.01
# Episode: 110  Reward: -2 Explore: 0.01
# Episode: 111  Reward: -271 Explore: 0.01
# Episode: 112  Reward: -132 Explore: 0.01
# Episode: 113  Reward: -268 Explore: 0.00
# Episode: 114  Reward: -506 Explore: 0.00
# Episode: 115  Reward: -272 Explore: 0.00
# Episode: 116  Reward: -421 Explore: 0.00
# Episode: 117  Reward: -126 Explore: 0.00
# Episode: 118  Reward: -520 Explore: 0.00
# Episode: 119  Reward: -247 Explore: 0.00
# Episode: 120  Reward: -132 Explore: 0.00
# Episode: 121  Reward: -531 Explore: 0.00
# Episode: 122  Reward: -278 Explore: 0.00
# Episode: 123  Reward: -137 Explore: 0.00
# Episode: 124  Reward: -276 Explore: 0.00
# Episode: 125  Reward: -302 Explore: 0.00
# Episode: 126  Reward: -509 Explore: 0.00
# Episode: 127  Reward: -264 Explore: 0.00
# Episode: 128  Reward: -420 Explore: 0.00
# Episode: 129  Reward: -131 Explore: 0.00
# Episode: 130  Reward: -282 Explore: 0.00
# Episode: 131  Reward: -1206 Explore: 0.00
# Episode: 132  Reward: -1245 Explore: 0.00
# Episode: 133  Reward: -9 Explore: 0.00
# Episode: 134  Reward: -408 Explore: 0.00
# Episode: 135  Reward: -138 Explore: 0.00
# Episode: 136  Reward: -439 Explore: 0.00
# Episode: 137  Reward: -263 Explore: 0.00
# Episode: 138  Reward: -139 Explore: 0.00
# Episode: 139  Reward: -405 Explore: 0.00
# Episode: 140  Reward: -138 Explore: 0.00
# Episode: 141  Reward: -308 Explore: 0.00
# Episode: 142  Reward: -132 Explore: 0.00
# Episode: 143  Reward: -9 Explore: 0.00
# Episode: 144  Reward: -1533 Explore: 0.00
# Episode: 145  Reward: -931 Explore: 0.00
# Episode: 146  Reward: -553 Explore: 0.00
# Episode: 147  Reward: -127 Explore: 0.00
# Episode: 148  Reward: -374 Explore: 0.00
# Episode: 149  Reward: -129 Explore: 0.00
# Episode: 150  Reward: -259 Explore: 0.00
# Episode: 151  Reward: -1495 Explore: 0.00
# Episode: 152  Reward: -259 Explore: 0.00
# Episode: 153  Reward: -262 Explore: 0.00
# Episode: 154  Reward: -261 Explore: 0.00
# Episode: 155  Reward: -128 Explore: 0.00
# Episode: 156  Reward: -268 Explore: 0.00
# Episode: 157  Reward: -435 Explore: 0.00
# Episode: 158  Reward: -344 Explore: 0.00
# Episode: 159  Reward: -430 Explore: 0.00
# Episode: 160  Reward: -391 Explore: 0.00
# Episode: 161  Reward: -814 Explore: 0.00
# Episode: 162  Reward: -497 Explore: 0.00
# Episode: 163  Reward: -385 Explore: 0.00
# Episode: 164  Reward: -515 Explore: 0.00
# Episode: 165  Reward: -128 Explore: 0.00
# Episode: 166  Reward: -125 Explore: 0.00
# Episode: 167  Reward: -134 Explore: 0.00
# Episode: 168  Reward: -131 Explore: 0.00
# Episode: 169  Reward: -134 Explore: 0.00
# Episode: 170  Reward: -254 Explore: 0.00
# Episode: 171  Reward: -392 Explore: 0.00
# Episode: 172  Reward: -138 Explore: 0.00
# Episode: 173  Reward: -6 Explore: 0.00
# Episode: 174  Reward: -1492 Explore: 0.00
# Episode: 175  Reward: -276 Explore: 0.00
# Episode: 176  Reward: -260 Explore: 0.00
# Episode: 177  Reward: 0 Explore: 0.00
# Episode: 178  Reward: -256 Explore: 0.00
# Episode: 179  Reward: -261 Explore: 0.00
# Episode: 180  Reward: -265 Explore: 0.00
# Episode: 181  Reward: -1 Explore: 0.00
# Episode: 182  Reward: -269 Explore: 0.00
# Episode: 183  Reward: -271 Explore: 0.00
# Episode: 184  Reward: -266 Explore: 0.00
# Episode: 185  Reward: -129 Explore: 0.00
# Episode: 186  Reward: -273 Explore: 0.00
# Episode: 187  Reward: -133 Explore: 0.00
# Episode: 188  Reward: -314 Explore: 0.00
# Episode: 189  Reward: -393 Explore: 0.00
# Episode: 190  Reward: -393 Explore: 0.00
# Episode: 191  Reward: -267 Explore: 0.00
# Episode: 192  Reward: -545 Explore: 0.00
# Episode: 193  Reward: -403 Explore: 0.00
# Episode: 194  Reward: -394 Explore: 0.00
# Episode: 195  Reward: -135 Explore: 0.00
# Episode: 196  Reward: -263 Explore: 0.00
# Episode: 197  Reward: -261 Explore: 0.00
# Episode: 198  Reward: -142 Explore: 0.00
# Episode: 199  Reward: -331 Explore: 0.00
# Episode: 200  Reward: -418 Explore: 0.00
# episode:  200 Evaluation Average Reward: -3.2835222344063286
# Episode: 201  Reward: -383 Explore: 0.00
# Episode: 202  Reward: -254 Explore: 0.00
# Episode: 203  Reward: -138 Explore: 0.00
# Episode: 204  Reward: -261 Explore: 0.00
# Episode: 205  Reward: -135 Explore: 0.00
# Episode: 206  Reward: -383 Explore: 0.00
# Episode: 207  Reward: -8 Explore: 0.00
# Episode: 208  Reward: -406 Explore: 0.00
# Episode: 209  Reward: -133 Explore: 0.00
# Episode: 210  Reward: -137 Explore: 0.00
# Episode: 211  Reward: -524 Explore: 0.00
# Episode: 212  Reward: -879 Explore: 0.00
# Episode: 213  Reward: -4 Explore: 0.00
# Episode: 214  Reward: -9 Explore: 0.00
# Episode: 215  Reward: -1518 Explore: 0.00
# Episode: 216  Reward: -1436 Explore: 0.00
# Episode: 217  Reward: -376 Explore: 0.00
# Episode: 218  Reward: -5 Explore: 0.00
# Episode: 219  Reward: -525 Explore: 0.00
# Episode: 220  Reward: -1031 Explore: 0.00
# Episode: 221  Reward: -528 Explore: 0.00
# Episode: 222  Reward: -122 Explore: 0.00
# Episode: 223  Reward: -410 Explore: 0.00
# Episode: 224  Reward: -134 Explore: 0.00
# Episode: 225  Reward: -265 Explore: 0.00
# Episode: 226  Reward: -284 Explore: 0.00
# Episode: 227  Reward: -294 Explore: 0.00
# Episode: 228  Reward: -140 Explore: 0.00
# Episode: 229  Reward: -253 Explore: 0.00
# Episode: 230  Reward: -145 Explore: 0.00
# Episode: 231  Reward: -7 Explore: 0.00
# Episode: 232  Reward: -135 Explore: 0.00
# Episode: 233  Reward: -139 Explore: 0.00
# Episode: 234  Reward: -129 Explore: 0.00
# Episode: 235  Reward: -9 Explore: 0.00
# Episode: 236  Reward: -542 Explore: 0.00
# Episode: 237  Reward: -410 Explore: 0.00
# Episode: 238  Reward: -279 Explore: 0.00
# Episode: 239  Reward: -137 Explore: 0.00
# Episode: 240  Reward: -8 Explore: 0.00
# Episode: 241  Reward: -1495 Explore: 0.00
# Episode: 242  Reward: -9 Explore: 0.00
# Episode: 243  Reward: -129 Explore: 0.00
# Episode: 244  Reward: -129 Explore: 0.00
# Episode: 245  Reward: -131 Explore: 0.00
# Episode: 246  Reward: -268 Explore: 0.00
# Episode: 247  Reward: -241 Explore: 0.00
# Episode: 248  Reward: -1 Explore: 0.00
# Episode: 249  Reward: -251 Explore: 0.00
# Episode: 250  Reward: -1491 Explore: 0.00
# Episode: 251  Reward: -258 Explore: 0.00
# Episode: 252  Reward: -264 Explore: 0.00
# Episode: 253  Reward: -268 Explore: 0.00
# Episode: 254  Reward: -252 Explore: 0.00
# Episode: 255  Reward: -132 Explore: 0.00
# Episode: 256  Reward: -137 Explore: 0.00
# Episode: 257  Reward: -406 Explore: 0.00
# Episode: 258  Reward: -138 Explore: 0.00
# Episode: 259  Reward: -7 Explore: 0.00
# Episode: 260  Reward: -125 Explore: 0.00
# Episode: 261  Reward: -9 Explore: 0.00
# Episode: 262  Reward: -140 Explore: 0.00
# Episode: 263  Reward: -263 Explore: 0.00
# Episode: 264  Reward: -135 Explore: 0.00
# Episode: 265  Reward: -250 Explore: 0.00
# Episode: 266  Reward: -131 Explore: 0.00
# Episode: 267  Reward: -135 Explore: 0.00
# Episode: 268  Reward: -7 Explore: 0.00
# Episode: 269  Reward: -240 Explore: 0.00
# Episode: 270  Reward: -130 Explore: 0.00
# Episode: 271  Reward: -136 Explore: 0.00
# Episode: 272  Reward: -242 Explore: 0.00
# Episode: 273  Reward: -265 Explore: 0.00
# Episode: 274  Reward: -343 Explore: 0.00
# Episode: 275  Reward: -133 Explore: 0.00
# Episode: 276  Reward: -7 Explore: 0.00
# Episode: 277  Reward: -130 Explore: 0.00
# Episode: 278  Reward: -369 Explore: 0.00
# Episode: 279  Reward: -128 Explore: 0.00
# Episode: 280  Reward: -130 Explore: 0.00
# Episode: 281  Reward: -136 Explore: 0.00
# Episode: 282  Reward: -256 Explore: 0.00
# Episode: 283  Reward: -422 Explore: 0.00
# Episode: 284  Reward: -126 Explore: 0.00
# Episode: 285  Reward: -534 Explore: 0.00
# Episode: 286  Reward: -525 Explore: 0.00
# Episode: 287  Reward: -130 Explore: 0.00
# Episode: 288  Reward: -385 Explore: 0.00
# Episode: 289  Reward: -131 Explore: 0.00
# Episode: 290  Reward: -257 Explore: 0.00
# Episode: 291  Reward: -316 Explore: 0.00
# Episode: 292  Reward: -382 Explore: 0.00
# Episode: 293  Reward: -413 Explore: 0.00
# Episode: 294  Reward: -262 Explore: 0.00
# Episode: 295  Reward: -293 Explore: 0.00
# Episode: 296  Reward: -260 Explore: 0.00
# Episode: 297  Reward: -232 Explore: 0.00
# Episode: 298  Reward: -1101 Explore: 0.00
# Episode: 299  Reward: -662 Explore: 0.00
# Episode: 300  Reward: -258 Explore: 0.00
# episode:  300 Evaluation Average Reward: -7.891062609980721
# Episode: 301  Reward: -116 Explore: 0.00
# Episode: 302  Reward: -1 Explore: 0.00
# Episode: 303  Reward: -128 Explore: 0.00
# Episode: 304  Reward: -130 Explore: 0.00
# Episode: 305  Reward: -1458 Explore: 0.00
# Episode: 306  Reward: -253 Explore: 0.00
# Episode: 307  Reward: -257 Explore: 0.00
# Episode: 308  Reward: -128 Explore: 0.00
# Episode: 309  Reward: -1503 Explore: 0.00
# Episode: 310  Reward: -135 Explore: 0.00
# Episode: 311  Reward: -125 Explore: 0.00
# Episode: 312  Reward: -2 Explore: 0.00
# Episode: 313  Reward: -1491 Explore: 0.00
# Episode: 314  Reward: -131 Explore: 0.00
# Episode: 315  Reward: -268 Explore: 0.00
# Episode: 316  Reward: -127 Explore: 0.00
# Episode: 317  Reward: -123 Explore: 0.00
# Episode: 318  Reward: -129 Explore: 0.00
# Episode: 319  Reward: -247 Explore: 0.00
# Episode: 320  Reward: -121 Explore: 0.00
# Episode: 321  Reward: -124 Explore: 0.00
# Episode: 322  Reward: -273 Explore: 0.00
# Episode: 323  Reward: -129 Explore: 0.00
# Episode: 324  Reward: -326 Explore: 0.00
# Episode: 325  Reward: -133 Explore: 0.00
# Episode: 326  Reward: -6 Explore: 0.00
# Episode: 327  Reward: -132 Explore: 0.00
# Episode: 328  Reward: -3 Explore: 0.00
# Episode: 329  Reward: -130 Explore: 0.00
# Episode: 330  Reward: -127 Explore: 0.00
# Episode: 331  Reward: 0 Explore: 0.00
# Episode: 332  Reward: -511 Explore: 0.00
# Episode: 333  Reward: -129 Explore: 0.00
# Episode: 334  Reward: -2 Explore: 0.00
# Episode: 335  Reward: -136 Explore: 0.00
# Episode: 336  Reward: -4 Explore: 0.00
# Episode: 337  Reward: -130 Explore: 0.00
# Episode: 338  Reward: -261 Explore: 0.00
# Episode: 339  Reward: -261 Explore: 0.00
# Episode: 340  Reward: -272 Explore: 0.00
# Episode: 341  Reward: -389 Explore: 0.00
# Episode: 342  Reward: -132 Explore: 0.00
# Episode: 343  Reward: -261 Explore: 0.00
# Episode: 344  Reward: -411 Explore: 0.00
# Episode: 345  Reward: -277 Explore: 0.00
# Episode: 346  Reward: -149 Explore: 0.00
# Episode: 347  Reward: -388 Explore: 0.00
# Episode: 348  Reward: -405 Explore: 0.00
# Episode: 349  Reward: -455 Explore: 0.00
# Episode: 350  Reward: -147 Explore: 0.00
# Episode: 351  Reward: -147 Explore: 0.00
# Episode: 352  Reward: -607 Explore: 0.00
# Episode: 353  Reward: -398 Explore: 0.00
# Episode: 354  Reward: -150 Explore: 0.00
# Episode: 355  Reward: -426 Explore: 0.00
# Episode: 356  Reward: -320 Explore: 0.00
# Episode: 357  Reward: -130 Explore: 0.00
# Episode: 358  Reward: -3 Explore: 0.00
# Episode: 359  Reward: -135 Explore: 0.00
# Episode: 360  Reward: -133 Explore: 0.00
# Episode: 361  Reward: -133 Explore: 0.00
# Episode: 362  Reward: -133 Explore: 0.00
# Episode: 363  Reward: -6 Explore: 0.00
# Episode: 364  Reward: -129 Explore: 0.00
# Episode: 365  Reward: -399 Explore: 0.00
# Episode: 366  Reward: -276 Explore: 0.00
# Episode: 367  Reward: -248 Explore: 0.00
# Episode: 368  Reward: -133 Explore: 0.00
# Episode: 369  Reward: -128 Explore: 0.00
# Episode: 370  Reward: -246 Explore: 0.00
# Episode: 371  Reward: -133 Explore: 0.00
# Episode: 372  Reward: -128 Explore: 0.00
# Episode: 373  Reward: -131 Explore: 0.00
# Episode: 374  Reward: -131 Explore: 0.00
# Episode: 375  Reward: -288 Explore: 0.00
# Episode: 376  Reward: -2 Explore: 0.00
# Episode: 377  Reward: -388 Explore: 0.00
# Episode: 378  Reward: -991 Explore: 0.00
# Episode: 379  Reward: -140 Explore: 0.00
# Episode: 380  Reward: -128 Explore: 0.00
# Episode: 381  Reward: -1182 Explore: 0.00
# Episode: 382  Reward: -1072 Explore: 0.00
# Episode: 383  Reward: -245 Explore: 0.00
# Episode: 384  Reward: -385 Explore: 0.00
# Episode: 385  Reward: -337 Explore: 0.00
# Episode: 386  Reward: -134 Explore: 0.00
# Episode: 387  Reward: -446 Explore: 0.00
# Episode: 388  Reward: -948 Explore: 0.00
# Episode: 389  Reward: -1230 Explore: 0.00
# Episode: 390  Reward: -272 Explore: 0.00
# Episode: 391  Reward: -795 Explore: 0.00
# Episode: 392  Reward: -1006 Explore: 0.00
# Episode: 393  Reward: -789 Explore: 0.00
# Episode: 394  Reward: -767 Explore: 0.00
# Episode: 395  Reward: -535 Explore: 0.00
# Episode: 396  Reward: -145 Explore: 0.00
# Episode: 397  Reward: -138 Explore: 0.00
# Episode: 398  Reward: -275 Explore: 0.00
# Episode: 399  Reward: -274 Explore: 0.00
# Episode: 400  Reward: -1051 Explore: 0.00
# episode:  400 Evaluation Average Reward: -10.172370187723603
# Episode: 401  Reward: -1110 Explore: 0.00
# Episode: 402  Reward: -133 Explore: 0.00
# Episode: 403  Reward: -138 Explore: 0.00
# Episode: 404  Reward: -407 Explore: 0.00
# Episode: 405  Reward: -410 Explore: 0.00
# Episode: 406  Reward: -7 Explore: 0.00
# Episode: 407  Reward: -6 Explore: 0.00
# Episode: 408  Reward: -132 Explore: 0.00
# Episode: 409  Reward: -1492 Explore: 0.00
# Episode: 410  Reward: -271 Explore: 0.00
# Episode: 411  Reward: -284 Explore: 0.00
# Episode: 412  Reward: -274 Explore: 0.00
# Episode: 413  Reward: -406 Explore: 0.00
# Episode: 414  Reward: -936 Explore: 0.00
# Episode: 415  Reward: -945 Explore: 0.00
# Episode: 416  Reward: -917 Explore: 0.00
# Episode: 417  Reward: -971 Explore: 0.00
# Episode: 418  Reward: -923 Explore: 0.00
# Episode: 419  Reward: -807 Explore: 0.00
# Episode: 420  Reward: -939 Explore: 0.00
# Episode: 421  Reward: -404 Explore: 0.00
# Episode: 422  Reward: -280 Explore: 0.00
# Episode: 423  Reward: -135 Explore: 0.00
# Episode: 424  Reward: 0 Explore: 0.00
# Episode: 425  Reward: -715 Explore: 0.00
# Episode: 426  Reward: -416 Explore: 0.00
# Episode: 427  Reward: -579 Explore: 0.00
# Episode: 428  Reward: -135 Explore: 0.00
# Episode: 429  Reward: -280 Explore: 0.00
# Episode: 430  Reward: -518 Explore: 0.00
# Episode: 431  Reward: -139 Explore: 0.00
# Episode: 432  Reward: -135 Explore: 0.00
# Episode: 433  Reward: -265 Explore: 0.00
# Episode: 434  Reward: -130 Explore: 0.00
# Episode: 435  Reward: -129 Explore: 0.00
